# %% [markdown]
# # Yahoo Finance web scraping with python

# %% [markdown]
# We will extract the key financial data of the major players in the automotive market.
# **************************************************************************************************************************
# BMW.DE = Bayerische Motoren Werke Aktiengesellschaft
#
# VLKAF = Volkswagen AG
#
# TM = Toyota Motor Corporation
#
# F = Ford Motor Company
#
# GM = General Motors Company
# **************************************************************************************************************************

# %% [markdown]
# ### Lets extract the data for BMW first

# %%
#Packages
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
#Initialisation
url = 'https://fr.finance.yahoo.com/quote/BMW.DE/key-statistics'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

# %%
#Request
response = requests.get(url, headers=headers)

#Soup
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

# %%
#Deep dive in the HTML
tables = soup.find_all('table')

for table in tables:
    print(table.prettify())
# Out:
# <table class="W(100%) Bdcl(c)">
#  <tbody>
#   <tr class="Bxz(bb) H(36px) BdY Bdc($seperatorColor) fi-row Bgc($hoverBgColor):h">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px) Miw(140px)">
#     <span>
#      Cap. boursière (intrajournalière)
#     </span>
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     56.23B
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor) fi-row Bgc($hoverBgColor):h">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Valeur de l’entreprise
#     </span>
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     106.32B
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor) fi-row Bgc($hoverBgColor):h">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      P/E précédent
#     </span>
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     5.28
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor) fi-row Bgc($hoverBgColor):h">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      P/E à terme
#     </span>
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     5.25
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor) fi-row Bgc($hoverBgColor):h">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Rapport PEG (prévu sur 5 ans)
#     </span>
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     17.52
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor) fi-row Bgc($hoverBgColor):h">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Cours/Ventes
#     </span>
#     <!-- -->
#     (ttm)
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     0.33
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor) fi-row Bgc($hoverBgColor):h">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Cours/Registre comptable
#     </span>
#     <!-- -->
#     (dern. trim.)
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     0.61
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor) fi-row Bgc($hoverBgColor):h">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Valeur d’entreprise/Chiffre d’affaires
#     </span>
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     0.68
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor) fi-row Bgc($hoverBgColor):h">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Valeur de l’entreprise/EBITDA
#     </span>
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     4.13
#    </td>
#   </tr>
#  </tbody>
# </table>
#
# <table class="W(100%) Bdcl(c)">
#  <tbody>
#   <tr class="Bxz(bb) H(36px) BdY Bdc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px) Miw(140px)">
#     <span>
#      Bêta (mensuel sur 5 ans)
#     </span>
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     1,10
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Variation sur 52 semaines
#     </span>
#     <sup aria-label="Données provenant de plusieurs sources ou établies par Yahoo Finance.">
#      3
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     -18,85 %
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Variation S&amp;P500 sur 52 semaines
#     </span>
#     <sup aria-label="Données provenant de plusieurs sources ou établies par Yahoo Finance.">
#      3
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     25,22 %
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Plus haut annuel
#     </span>
#     <sup aria-label="Données provenant de plusieurs sources ou établies par Yahoo Finance.">
#      3
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     115,35
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Plus bas annuel
#     </span>
#     <sup aria-label="Données provenant de plusieurs sources ou établies par Yahoo Finance.">
#      3
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     86,54
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Moyenne mobile sur 50 jours
#     </span>
#     <sup aria-label="Données provenant de plusieurs sources ou établies par Yahoo Finance.">
#      3
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     98,61
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Moyenne mobile sur 200 jours
#     </span>
#     <sup aria-label="Données provenant de plusieurs sources ou établies par Yahoo Finance.">
#      3
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     99,17
#    </td>
#   </tr>
#  </tbody>
# </table>
#
# <table class="W(100%) Bdcl(c)">
#  <tbody>
#   <tr class="Bxz(bb) H(36px) BdY Bdc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px) Miw(140px)">
#     <span>
#      Vol. moy. (3 mois)
#     </span>
#     <sup aria-label="Données provenant de plusieurs sources ou établies par Yahoo Finance.">
#      3
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     1,06M
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Vol. moy. (10 jours)
#     </span>
#     <sup aria-label="Données provenant de plusieurs sources ou établies par Yahoo Finance.">
#      3
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     989,85k
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Actions en attente
#     </span>
#     <sup aria-label="Les actions en attente sont tirées du dernier rapport trimestriel ou annuel. Elles servent de support au calcul de la capitalisation boursière.">
#      5
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     579,8M
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Actions implicites en circulation
#     </span>
#     <sup aria-label="Actions en circulation de fonds propres, partant implicitement du principe que tous les fonds propres de filiales sont convertibles en actions ordinaires.">
#      6
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     635,06M
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Flottant
#     </span>
#     <sup aria-label="Les moyens de paiement en cours d’encaissement d'une entreprise est une mesure du nombre d'actions disponibles auprès du public pour la transaction. Il s’obtient en soustrayant les actions restreintes (qui ne peuvent pas être cotées en bourse) du nombre d'actions émises et en circulation.">
#      8
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     406,17M
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      % détenu par des initiés
#     </span>
#     <sup aria-label="Données fournies par Refinitiv.">
#      1
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     48,56 %
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      % détenu par des institutions
#     </span>
#     <sup aria-label="Données fournies par Refinitiv.">
#      1
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     22,85 %
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Actions vendues à découvert au
#     </span>
#     <sup aria-label="Données fournies par Morningstar, Inc.">
#      4
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     <span>
#      S.O.
#     </span>
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Ratio VAD au
#     </span>
#     <sup aria-label="Données fournies par Morningstar, Inc.">
#      4
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     <span>
#      S.O.
#     </span>
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      % des paiements en cours d’encaissement au
#     </span>
#     <sup aria-label="Données fournies par Morningstar, Inc.">
#      4
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     <span>
#      S.O.
#     </span>
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      % d’actions en circulation VAD au
#     </span>
#     <sup aria-label="Données fournies par Morningstar, Inc.">
#      4
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     <span>
#      S.O.
#     </span>
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Actions vendues à découvert (avant le )
#     </span>
#     <sup aria-label="Données fournies par Morningstar, Inc.">
#      4
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     <span>
#      S.O.
#     </span>
#    </td>
#   </tr>
#  </tbody>
# </table>
#
# <table class="W(100%) Bdcl(c)">
#  <tbody>
#   <tr class="Bxz(bb) H(36px) BdY Bdc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px) Miw(140px)">
#     <span>
#      Taux de dividende annuel à terme
#     </span>
#     <sup aria-label="Données fournies par Morningstar, Inc.">
#      4
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     6
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Rendement en dividende annuel à terme
#     </span>
#     <sup aria-label="Données fournies par Morningstar, Inc.">
#      4
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     6,78 %
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Taux de dividende annuel précédent
#     </span>
#     <sup aria-label="Données provenant de plusieurs sources ou établies par Yahoo Finance.">
#      3
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     6,00
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Rendement du dividende annuel précédent
#     </span>
#     <sup aria-label="Données provenant de plusieurs sources ou établies par Yahoo Finance.">
#      3
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     6,78 %
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Rendement en dividendes moyen sur 5 ans
#     </span>
#     <sup aria-label="Données fournies par Morningstar, Inc.">
#      4
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     5,42
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Rapport de distribution
#     </span>
#     <sup aria-label="Données fournies par Morningstar, Inc.">
#      4
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     50,66 %
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Date du dividende
#     </span>
#     <sup aria-label="Données provenant de plusieurs sources ou établies par Yahoo Finance.">
#      3
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     <span>
#      S.O.
#     </span>
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Date ex-dividende
#     </span>
#     <sup aria-label="Données fournies par Morningstar, Inc.">
#      4
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     16 mai 2024
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Dernier facteur de fractionnement
#     </span>
#     <sup aria-label="Données fournies par EDGAR Online.">
#      2
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     <span>
#      S.O.
#     </span>
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Dernière date de division
#     </span>
#     <sup aria-label="Données provenant de plusieurs sources ou établies par Yahoo Finance.">
#      3
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     <span>
#      S.O.
#     </span>
#    </td>
#   </tr>
#  </tbody>
# </table>
#
# <table class="W(100%) Bdcl(c)">
#  <tbody>
#   <tr class="Bxz(bb) H(36px) BdY Bdc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px) Miw(140px)">
#     <span>
#      Fin de l’exercice financier
#     </span>
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     31 déc. 2023
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Dernier trimestre
#     </span>
#     <!-- -->
#     (dern. trim.)
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     31 mars 2024
#    </td>
#   </tr>
#  </tbody>
# </table>
#
# <table class="W(100%) Bdcl(c)">
#  <tbody>
#   <tr class="Bxz(bb) H(36px) BdY Bdc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px) Miw(140px)">
#     <span>
#      Marge bénéficiaire
#     </span>
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     6,87 %
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Marge d’exploitation
#     </span>
#     <!-- -->
#     (ttm)
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     11,12 %
#    </td>
#   </tr>
#  </tbody>
# </table>
#
# <table class="W(100%) Bdcl(c)">
#  <tbody>
#   <tr class="Bxz(bb) H(36px) BdY Bdc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px) Miw(140px)">
#     <span>
#      Rendement des actifs
#     </span>
#     <!-- -->
#     (ttm)
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     4,25 %
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Rendement des capitaux propres
#     </span>
#     <!-- -->
#     (ttm)
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     12,09 %
#    </td>
#   </tr>
#  </tbody>
# </table>
#
# <table class="W(100%) Bdcl(c)">
#  <tbody>
#   <tr class="Bxz(bb) H(36px) BdY Bdc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px) Miw(140px)">
#     <span>
#      Chiffre d'affaires
#     </span>
#     <!-- -->
#     (ttm)
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     155,26B
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Revenu par action
#     </span>
#     <!-- -->
#     (ttm)
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     243,45
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Croissance trimestrielle du chiffre d’affaires
#     </span>
#     <!-- -->
#     (Sur 12 mois)
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     -0,60 %
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Bénéfice brut
#     </span>
#     <!-- -->
#     (ttm)
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     <span>
#      S.O.
#     </span>
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      EBITDA
#     </span>
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     22,74B
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Bénéfice net disponible distribuable
#     </span>
#     <!-- -->
#     (ttm)
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     10,66B
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      BPA dilué
#     </span>
#     <!-- -->
#     (ttm)
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     16,78
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Croissance trimestrielle des bénéfices
#     </span>
#     <!-- -->
#     (Sur 12 mois)
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     -18,40 %
#    </td>
#   </tr>
#  </tbody>
# </table>
#
# <table class="W(100%) Bdcl(c)">
#  <tbody>
#   <tr class="Bxz(bb) H(36px) BdY Bdc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px) Miw(140px)">
#     <span>
#      Trésorerie totale
#     </span>
#     <!-- -->
#     (dern. trim.)
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     12,83B
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Total d’espèces par action
#     </span>
#     <!-- -->
#     (dern. trim.)
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     20,25
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Dette totale
#     </span>
#     <!-- -->
#     (dern. trim.)
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     95,14B
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Dette/Actif total
#     </span>
#     <!-- -->
#     (dern. trim.)
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     99,48 %
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Coefficient de liquidité
#     </span>
#     <!-- -->
#     (dern. trim.)
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     1,13
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Valeur comptable par action
#     </span>
#     <!-- -->
#     (dern. trim.)
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     141,42
#    </td>
#   </tr>
#  </tbody>
# </table>
#
# <table class="W(100%) Bdcl(c)">
#  <tbody>
#   <tr class="Bxz(bb) H(36px) BdY Bdc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px) Miw(140px)">
#     <span>
#      Flux de trésorerie d’exploitation
#     </span>
#     <!-- -->
#     (ttm)
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     13,29B
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Effet de levier de flux de trésorerie libre
#     </span>
#     <!-- -->
#     (ttm)
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     4,61B
#    </td>
#   </tr>
#  </tbody>
# </table>

# %%
#Isolate the right table
financial_table = tables[7]
print(financial_table.prettify())
# Out:
# <table class="W(100%) Bdcl(c)">
#  <tbody>
#   <tr class="Bxz(bb) H(36px) BdY Bdc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px) Miw(140px)">
#     <span>
#      Chiffre d'affaires
#     </span>
#     <!-- -->
#     (ttm)
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     155,26B
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Revenu par action
#     </span>
#     <!-- -->
#     (ttm)
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     243,45
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Croissance trimestrielle du chiffre d’affaires
#     </span>
#     <!-- -->
#     (Sur 12 mois)
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     -0,60 %
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Bénéfice brut
#     </span>
#     <!-- -->
#     (ttm)
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     <span>
#      S.O.
#     </span>
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      EBITDA
#     </span>
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     22,74B
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Bénéfice net disponible distribuable
#     </span>
#     <!-- -->
#     (ttm)
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     10,66B
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      BPA dilué
#     </span>
#     <!-- -->
#     (ttm)
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     16,78
#    </td>
#   </tr>
#   <tr class="Bxz(bb) H(36px) BdB Bdbc($seperatorColor)">
#    <td class="Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)">
#     <span>
#      Croissance trimestrielle des bénéfices
#     </span>
#     <!-- -->
#     (Sur 12 mois)
#     <sup aria-label="">
#     </sup>
#    </td>
#    <td class="Fw(500) Ta(end) Pstart(10px) Miw(60px)">
#     -18,40 %
#    </td>
#   </tr>
#  </tbody>
# </table>

# %%
#Extract the rows

rows=financial_table.find_all('tr')
data=[]
for row in rows:
    cols = row.find_all('td')
    cols = [col.text.strip() for col in cols]
    data.append(cols)
    print(cols)
# Out:
# ["Chiffre d'affaires (ttm)", '155,26B']
# ['Revenu par action (ttm)', '243,45']
# ['Croissance trimestrielle du chiffre d’affaires (Sur 12\xa0mois)', '-0,60 %']
# ['Bénéfice brut (ttm)', 'S.O.']
# ['EBITDA', '22,74B']
# ['Bénéfice net disponible distribuable (ttm)', '10,66B']
# ['BPA dilué (ttm)', '16,78']
# ['Croissance trimestrielle des bénéfices (Sur 12\xa0mois)', '-18,40 %']

# %% [markdown]
# ### Now we want to create a function that will gather all the information we need for each symbol.

# %%
# The fonction :

def extract_financial_data(symbol):
    url = f'https://fr.finance.yahoo.com/quote/{symbol}/key-statistics'
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}
    response = requests.get(url, headers=headers)
    
    if response.status_code == 200:
        page_content = response.text
    else:
        print(f"Error retrieving the page {symbol}")
        return
    
    soup = BeautifulSoup(page_content, 'html.parser')
    tables = soup.find_all('table')
    
    if len(tables) < 8:
        print(f"Less than 8 tables found for {symbol}")
        return
    
    # select  the 7th table
    financial_table = tables[7]
    
    # Extract the rows
    rows = financial_table.find_all('tr')
    data = []
    for row in rows:
        cols = row.find_all('td')
        cols = [col.text.strip() for col in cols]
        if cols:  # Adding non empty rows 
            data.append([symbol] + cols)
    
    # DataFrame
    df = pd.DataFrame(data, columns=['Symbol'] + [f'Col{i}' for i in range(1, len(data[0]))])
    
    return df

# %%
#Pull the data 
symbol = 'F'
df1 = extract_financial_data(symbol)
symbol ='VLKAF'
df2 = extract_financial_data(symbol)
symbol ='GM'
df3 = extract_financial_data(symbol)
symbol ='TM'
df4 = extract_financial_data(symbol)
symbol ='BMW.DE'
df5 = extract_financial_data(symbol)

df_append=df1.append([df2,df3,df4,df5])
print(df_append)
# Out:
#    Symbol                                               Col1      Col2
# 0       F                           Chiffre d'affaires (ttm)   177,49B
# 1       F                            Revenu par action (ttm)     44,43
# 2       F  Croissance trimestrielle du chiffre d’affaires...    3,10 %
# 3       F                                Bénéfice brut (ttm)      S.O.
# 4       F                                             EBITDA    11,08B
# 5       F         Bénéfice net disponible distribuable (ttm)     3,92B
# 6       F                                    BPA dilué (ttm)      0,97
# 7       F  Croissance trimestrielle des bénéfices (Sur 12...  -24,20 %
# 0   VLKAF                           Chiffre d'affaires (ttm)   321,55B
# 1   VLKAF                            Revenu par action (ttm)    641,43
# 2   VLKAF  Croissance trimestrielle du chiffre d’affaires...   -1,00 %
# 3   VLKAF                                Bénéfice brut (ttm)      S.O.
# 4   VLKAF                                             EBITDA    31,79B
# 5   VLKAF         Bénéfice net disponible distribuable (ttm)    15,07B
# 6   VLKAF                                    BPA dilué (ttm)     32,15
# 7   VLKAF  Croissance trimestrielle des bénéfices (Sur 12...  -21,10 %
# 0      GM                           Chiffre d'affaires (ttm)   174,87B
# 1      GM                            Revenu par action (ttm)    134,13
# 2      GM  Croissance trimestrielle du chiffre d’affaires...    7,60 %
# 3      GM                                Bénéfice brut (ttm)      S.O.
# 4      GM                                             EBITDA    16,88B
# 5      GM         Bénéfice net disponible distribuable (ttm)    10,62B
# 6      GM                                    BPA dilué (ttm)      8,19
# 7      GM  Croissance trimestrielle des bénéfices (Sur 12...   24,40 %
# 0      TM                           Chiffre d'affaires (ttm)     45,1T
# 1      TM                            Revenu par action (ttm)  2 085,76
# 2      TM  Croissance trimestrielle du chiffre d’affaires...   14,30 %
# 3      TM                                Bénéfice brut (ttm)      S.O.
# 4      TM                                             EBITDA     7,44T
# 5      TM         Bénéfice net disponible distribuable (ttm)     4,94T
# 6      TM                                    BPA dilué (ttm)     23,22
# 7      TM  Croissance trimestrielle des bénéfices (Sur 12...   80,60 %
# 0  BMW.DE                           Chiffre d'affaires (ttm)   155,26B
# 1  BMW.DE                            Revenu par action (ttm)    243,45
# 2  BMW.DE  Croissance trimestrielle du chiffre d’affaires...   -0,60 %
# 3  BMW.DE                                Bénéfice brut (ttm)      S.O.
# 4  BMW.DE                                             EBITDA    22,74B
# 5  BMW.DE         Bénéfice net disponible distribuable (ttm)    10,66B
# 6  BMW.DE                                    BPA dilué (ttm)     16,78
# 7  BMW.DE  Croissance trimestrielle des bénéfices (Sur 12...  -18,40 %

# %%
# Export the data to CSV
if df_append is not None:
    df_append.to_csv('financial_data.csv', index=False)

# %% [markdown]
# ### Your data is now waiting for you to be cleaned up and analyzed!
